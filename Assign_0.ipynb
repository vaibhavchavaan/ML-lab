# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

operation = input("Enter operation (add, subtract, multiply, divide, modulo, power): ")

match operation:
    case 'add':
        print("Result:", a + b)

    case 'subtract':
        print("Result:", a - b)

    case 'multiply':
        print("Result:", a * b)

    case 'divide':
        if b == 0:
            print("Error: Division by zero")
        else:
            print("Result:", a / b)

    case 'modulo':
        if b == 0:
            print("Error: Modulo by zero")
        else:
            print("Result:", a % b)

    case 'power':
        print("Result:", a ** b)

    case _:
        print("Invalid operation")
# Out:
# Enter first number:  2
# Enter second number:  3
# Enter operation (add, subtract, multiply, divide, modulo, power):  add
# Result: 5.0

# %%
import matplotlib.pyplot as plt

x = [5]
y = [7]


plt.scatter(x, y, color='red')
plt.title("Single Point Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()
